# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.

# %%
df = pd.read_csv('USA_Housing.csv')
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# # 2.

# %%
df.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
df.tail(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4990      52723.876555             5.452237                   8.124571
# 4991      74102.191890             5.657841                   7.683993
# 4992      87499.125743             6.403473                   4.836091
# 4993      69639.140896             5.007510                   7.778375
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4990                          6.39     14802.088438  4.795006e+05
# ...

# %%
df.sample(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1651      63700.262473             5.375149                   7.723660
# 4846      68672.560801             6.136061                   6.820187
# 3814      67622.219611             5.813928                   5.071112
# 2642      80366.374810             6.614015                   7.308434
# 3233      62060.942658             5.952779                   4.498699
# 3576      62384.572515             6.500024                   7.693402
# 4055      73334.683867             5.305892                   5.954194
# 1691      59013.403470             5.443617                   5.854420
# 2822      73086.238207             6.648407                   6.395176
# 765       62636.830096             5.863607                   5.796623
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 1651                          6.20     38397.566948  9.541542e+05
# ...

# %% [markdown]
# # 3.

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %% [markdown]
# # 4.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# # 5.

# %%
sns.pairplot(df)

# %% [markdown]
# # 6.

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.distplot(df['Avg. Area Income'])

# %%
sns.distplot(df['Avg. Area House Age'])

# %%
sns.distplot(df['Avg. Area Number of Rooms'])

# %%
sns.distplot(df['Avg. Area Number of Bedrooms'])

# %%
sns.distplot(df['Area Population'])

# %%
sns.distplot(df['Price'])

# %% [markdown]
# # 7.

# %%
columns = ['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population','Price']
df_corr = df[columns].corr()
df_corr
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
fig = plt.figure(figsize=(8,6))
sns.heatmap(df_corr)

# %% [markdown]
# # 8.

# %%
fig = plt.figure(figsize=(8,6))
sns.scatterplot(data=df,x='Avg. Area Income',y='Price')

# %% [markdown]
# # 9.

# %%
fig = plt.figure(figsize=(8,6))
sns.scatterplot(data=df,x='Avg. Area Number of Bedrooms',y='Area Population')

# %% [markdown]
# # 10.

# %%
sns.distplot(df['Price'])

# %% [markdown]
# # 11.

# %%
sns.boxplot(df['Price'],orient='v')

# %% [markdown]
# # 12.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X = df['Avg. Area Income']
y = df['Price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=100)

# %% [markdown]
# # 13.

# %%
X_train = np.array(X_train).reshape(-1,1)
X_test = np.array(X_test).reshape(-1,1)

ln = LinearRegression()
ln.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # 14.

# %%
y_predicted = ln.predict(X_test)

print('MAE: ',metrics.mean_absolute_error(y_test,y_predicted))
print('MSE: ',metrics.mean_squared_error(y_test,y_predicted))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_predicted)))
# Out:
# MAE:  209970.60351924415
# MSE:  70181811881.3643
# RMSE:  264918.50045129785

# %% [markdown]
# # 15.

# %%
sns.distplot(y_test-y_predicted,bins=50)

# %% [markdown]
# # 16.

# %%
x = X_test.flatten().tolist()
y = y_test.values.tolist()
sns.scatterplot(x,y)
sns.lineplot(x,ln.predict(X_test),color='r')

# %% [markdown]
# # 17.

# %%
X = df[['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']]
y = df['Price']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=100)

ln = LinearRegression()
ln.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # 18.

# %%
y_predicted = ln.predict(X_test)

print('MAE: ',metrics.mean_absolute_error(y_test,y_predicted))
print('MSE: ',metrics.mean_squared_error(y_test,y_predicted))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,y_predicted)))
# Out:
# MAE:  81758.98219476301
# MSE:  10366319820.241177
# RMSE:  101815.12569476687

# %% [markdown]
# # 19.

# %%
sns.distplot(y_test-y_predicted,bins=50)

# %% [markdown]
# # 20.

# %%
rsme_all_feature = 101815.12569476687
rsme_best_simple = 264918.50045129785
diff = rsme_best_simple-rsme_all_feature
print('แบบ all feature ดีกว่าแบบ simple = ',diff)
# Out:
# แบบ all feature ดีกว่าแบบ simple =  163103.37475653097
