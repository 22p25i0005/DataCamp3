# %% [markdown]
# # Part 1.

# %% [markdown]
# # 1.

# %%
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # 2.

# %%
df.sample(10)
# Out:
#         Rank                                           Name Platform    Year  \
# 16034  16037                    WinBack 2: Project Poseidon      PS2  2006.0
# 11584  11586  Legend of the Guardians: The Owls of Ga'Hoole      PS3  2010.0
# 1218    1220                            Fight Night Round 4      PS3  2009.0
# 2730    2732                                     Spectrobes       DS  2007.0
# 15506  15509                            Meiji Toukyou Renka      PSP  2013.0
# 5293    5295                                 WWE Crush Hour      PS2  2003.0
# 12572  12574                     LEGO Batman: The Videogame       PC  2008.0
# 3721    3723                             Tales of Symphonia      PS3  2013.0
# 103      104                                  Battlefield 3      PS3  2011.0
# 6151    6153                    Dead to Rights: Retribution      PS3  2010.0
#
#               Genre                               Publisher  NA_Sales  \
# ...

# %%
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %% [markdown]
# # 3.

# %%
df3 = df['Platform'].value_counts().head(10)
df3
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# Name: Platform, dtype: int64

# %% [markdown]
# # 4.

# %%
df4 = df['Platform'].value_counts().tail(10)
df4
# Out:
# NES     98
# DC      52
# GEN     27
# NG      12
# SCD      6
# WS       6
# 3DO      3
# TG16     2
# GG       1
# PCFX     1
# Name: Platform, dtype: int64

# %% [markdown]
# # 5.

# %%
df5 = df['Genre'].value_counts().head(10)
df5
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Name: Genre, dtype: int64

# %% [markdown]
# # 6.

# %%
df6 = df['Genre'].value_counts().tail(10)
df6
# Out:
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %% [markdown]
# # 7.

# %%
df7 = df[df['Name'].apply(lambda x: 'Grand Theft Auto' in x)]
df7
# Out:
#         Rank                                               Name Platform  \
# 16        17                                 Grand Theft Auto V      PS3
# 17        18                      Grand Theft Auto: San Andreas      PS2
# 23        24                                 Grand Theft Auto V     X360
# 24        25                        Grand Theft Auto: Vice City      PS2
# 38        39                               Grand Theft Auto III      PS2
# 44        45                                 Grand Theft Auto V      PS4
# 51        52                                Grand Theft Auto IV     X360
# 56        57                                Grand Theft Auto IV      PS3
# 90        91             Grand Theft Auto: Liberty City Stories      PSP
# 197      198                                 Grand Theft Auto V     XOne
# 198      199                Grand Theft Auto: Vice City Stories      PSP
# 360      361             Grand Theft Auto: Liberty City Stories      PS2
# ...

# %% [markdown]
# # 8.

# %%
df8 = df[df['Name'].duplicated(keep=False)]
df8['Name'].unique().shape
# Out:
# (2775,)

# %% [markdown]
# # 9.

# %%
df9 = df[['Name','Platform']]
df9 = df9[df9.duplicated(keep=False)]
df9.groupby(['Name','Platform']).size()
# Out:
# Name                         Platform
# Madden NFL 13                PS3         2
# Need for Speed: Most Wanted  PC          2
#                              X360        2
# Sonic the Hedgehog           PS3         2
# Wii de Asobu: Metroid Prime  Wii         2
# dtype: int64

# %% [markdown]
# # 10.

# %%
df10 = df.drop_duplicates(['Name','Platform'])
df10
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # 11.

# %%
df11 = df[df['Name'].str.contains('FIFA 15')]
df11['Global_Sales'].sum()
# Out:
# 19.020000000000003

# %% [markdown]
# # 12.

# %%
df12 = df[df['Name'].str.contains('Grand Theft Auto V')]
df12['JP_Sales'].sum()
# Out:
# 1.3900000000000001

# %% [markdown]
# # 13.

# %%
df['count'] = 1
df13 = df[df['Name'].duplicated()]
df13 = df13.groupby('Name').sum()
df13['count']
# Out:
# Name
# 007: Quantum of Solace              5
# 007: The World is not Enough        1
# 11eyes: CrossOver                   1
# 18 Wheeler: American Pro Trucker    1
# 187: Ride or Die                    1
#                                    ..
# iCarly                              1
# iCarly 2: iJoin The Click!          1
# nail'd                              1
# pro evolution soccer 2011           5
# uDraw Studio: Instant Artist        1
# Name: count, Length: 2775, dtype: int64

# %% [markdown]
# # 14.

# %%
df14 = df.groupby('Publisher').sum()['Global_Sales'].sort_values()[::-1]
df14.to_frame()
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1786.56
# Electronic Arts                   1110.32
# Activision                         727.46
# Sony Computer Entertainment        607.50
# Ubisoft                            474.72
# ...                                   ...
# Takuyo                               0.01
# Otomate                              0.01
# Epic Games                           0.01
# Inti Creates                         0.01
# Interworks Unlimited, Inc.           0.01
#
# [578 rows x 1 columns]

# %% [markdown]
# # 15.

# %%
df15 = df[df['Name'].str.contains('Call of Duty')]
df15
# Out:
#         Rank                                          Name Platform    Year  \
# 29        30                Call of Duty: Modern Warfare 3     X360  2011.0
# 31        32                       Call of Duty: Black Ops     X360  2010.0
# 33        34                     Call of Duty: Black Ops 3      PS4  2015.0
# 34        35                    Call of Duty: Black Ops II      PS3  2012.0
# 35        36                    Call of Duty: Black Ops II     X360  2012.0
# 36        37                Call of Duty: Modern Warfare 2     X360  2009.0
# 37        38                Call of Duty: Modern Warfare 3      PS3  2011.0
# 40        41                       Call of Duty: Black Ops      PS3  2010.0
# 55        56                Call of Duty: Modern Warfare 2      PS3  2009.0
# 61        62                          Call of Duty: Ghosts     X360  2013.0
# 67        68                          Call of Duty: Ghosts      PS3  2013.0
# ...

# %% [markdown]
# # 16.

# %%
df16 = df15[df15['Platform']=='PC']
df16 = df16.sort_values(['EU_Sales'])[::-1]
df16.head(5)
# Out:
#       Rank                            Name Platform    Year    Genre  \
# 1769  1771  Call of Duty 4: Modern Warfare       PC  2007.0  Shooter
# 1037  1039  Call of Duty: Modern Warfare 3       PC  2011.0  Shooter
# 1126  1128         Call of Duty: Black Ops       PC     NaN  Shooter
# 2347  2349  Call of Duty: Modern Warfare 2       PC  2009.0  Shooter
# 1217  1219      Call of Duty: Black Ops II       PC  2012.0  Shooter
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 1769  Activision      0.00      1.12       0.0         0.03          1.15
# 1037  Activision      0.41      0.98       0.0         0.33          1.72
# 1126  Activision      0.58      0.81       0.0         0.24          1.63
# 2347  Activision      0.01      0.79       0.0         0.09          0.89
# 1217  Activision      0.63      0.69       0.0         0.21          1.53
#
#       count
# 1769      1
# 1037      1
# 1126      1
# 2347      1
# 1217      1

# %% [markdown]
# # 17.

# %%
df17 = df.groupby('Platform').sum()
df17['EU_Sales'].max()
# Out:
# 343.70999999999805

# %% [markdown]
# # 18.

# %%
df18 = df.groupby('Genre').mean()
df18['Other_Sales'].max()
# Out:
# 0.0783893129771001

# %% [markdown]
# # 19.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = df['Platform'].values
y = df['Global_Sales'].values

plt.figure(figsize=(13,8))
plt.bar(x,y)
plt.show()

# %% [markdown]
# # 20.

# %%
df20 = df.groupby('Publisher').sum()
df20 = df20[['Global_Sales']].sort_values(['Global_Sales'])[::-1].head(5)
df20
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1786.56
# Electronic Arts                   1110.32
# Activision                         727.46
# Sony Computer Entertainment        607.50
# Ubisoft                            474.72

# %%
import matplotlib.pyplot as plt
import numpy as np

# Creating plot 
fig = plt.figure(figsize =(10, 7)) 
print(df20.values.flatten())
plt.pie(df20.values.flatten(), labels = df20.index,textprops = dict(color ="white"),autopct='%1.1f%%') 
  
# show plot 
plt.show()
# Out:
# [1786.56 1110.32  727.46  607.5   474.72]

# %% [markdown]
# # 21.

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.countplot(x="Genre", data=df)

# %% [markdown]
# # 22.

# %%
df22 = df[(df['Name'].str.contains('Call of Duty')) & (df['Platform'].str.contains('X'))]
df22 = df22.groupby('Name').sum().sort_values(['Global_Sales'])[::-1].head(5)
df22[['Global_Sales']]
# Out:
#                                 Global_Sales
# Name
# Call of Duty: Modern Warfare 3         14.76
# Call of Duty: Black Ops                14.64
# Call of Duty: Black Ops II             13.73
# Call of Duty: Modern Warfare 2         13.51
# Call of Duty: Ghosts                   13.07

# %%
import seaborn as sns

fig = plt.figure(figsize=(14,6))
sns.barplot(x=df22.index , y='Global_Sales' , data = df22)

# %% [markdown]
# # 23.

# %%
import seaborn as sns
import numpy as np

df23 = df.groupby('Year').sum()
df23 = df23['NA_Sales'].to_frame()
fig = plt.figure(figsize=(14,6))
sns.lineplot(x=df23.index , y='NA_Sales' , data = df23)

# %% [markdown]
# # 24.

# %%
import seaborn as sns
import numpy as np

df24 = df.groupby('Genre').sum()
df24 = df24['Global_Sales'].to_frame()
fig = plt.figure(figsize=(14,6))
sns.stripplot(x=df24.index , y='Global_Sales' , data = df24)

# %% [markdown]
# # 25.

# %%
import seaborn as sns
import numpy as np

fig = plt.figure(figsize=(14,6))
sns.distplot(df['Year'])

# %% [markdown]
# # 26.

# %%
import seaborn as sns
import numpy as np

df26 = df.groupby('Year').sum()

fig = plt.figure(figsize=(16,6))
sns.barplot(x=df26.index , y='JP_Sales' , data = df26)

# %% [markdown]
# # Part 2.

# %% [markdown]
# # 1.

# %%
df_p2 = pd.read_csv('AB_NYC_2019.csv')
df_p2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # 2.

# %%
df_p2.sample(10)
# Out:
#              id                                               name    host_id  \
# 32649  25677687                      Peaceful Room in Williamsburg    6787261
# 46739  35415489               2 Bedroom Apartment Amazing Location  265413630
# 37973  30017676  KOREA FOOD TOWN! Affordable Price! Ideal for 1...  162496355
# 26203  20896281              Sun-filled Park Slope Gem - Location!   10262386
# 4449    3041973            Perfect 1BR / Doorman / 22 St & 2nd Ave    1475015
# 41460  32240590  Sonder | Stock Exchange | Stylish Studio + Kit...  219517861
# 19085  15165888                                    The Brass Shack   33346283
# 13110   9918524                 Queen size room near Columbia Uni.   24919557
# 19465  15529937                   Private room in busy location Br   98726662
# 30738  23784779      Downtown private room (Queen Bed) + BREAKFAST   19909972
#
#           host_name neighbourhood_group        neighbourhood  latitude  \
# ...

# %%
df_p2.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_p2.tail(10)
# Out:
#              id                                               name    host_id  \
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %% [markdown]
# # 3.

# %%
df_p2['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %% [markdown]
# # 4.

# %%
df_p2['neighbourhood'].value_counts().tail(10)
# Out:
# Westerleigh        2
# West Farms         2
# Lighthouse Hill    2
# Howland Hook       2
# Woodrow            1
# Richmondtown       1
# New Dorp           1
# Fort Wadsworth     1
# Rossville          1
# Willowbrook        1
# Name: neighbourhood, dtype: int64

# %% [markdown]
# # 5.

# %%
df_p2['neighbourhood_group'].value_counts().head(10)
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# # 6.

# %%
df_p2['neighbourhood_group'].value_counts().tail(10)
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# # 7.

# %%
df_p2.groupby(['neighbourhood']).mean()['price'].to_frame()
# Out:
#                       price
# neighbourhood
# Allerton          87.595238
# Arden Heights     67.250000
# Arrochar         115.000000
# Arverne          171.779221
# Astoria          117.187778
# ...                     ...
# Windsor Terrace  138.993631
# Woodhaven         67.170455
# Woodlawn          60.090909
# Woodrow          700.000000
# Woodside          85.097872
#
# [221 rows x 1 columns]

# %%
df_p2.groupby(['neighbourhood_group']).mean()['price'].to_frame()
# Out:
#                           price
# neighbourhood_group
# Bronx                 87.496792
# Brooklyn             124.383207
# Manhattan            196.875814
# Queens                99.517649
# Staten Island        114.812332

# %% [markdown]
# # 8.

# %%
df8_p2 = df_p2.groupby('room_type').mean()
df8_p2
# Out:
#                            id       host_id   latitude  longitude       price  \
# room_type
# Entire home/apt  1.843818e+07  6.175593e+07  40.728649 -73.960696  211.794246
# Private room     1.946893e+07  7.247514e+07  40.729208 -73.942924   89.780973
# Shared room      2.300378e+07  1.026241e+08  40.730514 -73.943343   70.127586
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt        8.506907          22.842418           1.306578
# Private room           5.377900          24.112962           1.445209
# Shared room            6.475000          16.600000           1.471726
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                       10.698335        111.920304
# Private room                           3.227717        111.203933
# Shared room                            4.662931        162.000862

# %%
df8_p2[df8_p2['price'] == df8_p2['price'].max()]
# Out:
#                            id       host_id   latitude  longitude       price  \
# room_type
# Entire home/apt  1.843818e+07  6.175593e+07  40.728649 -73.960696  211.794246
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt        8.506907          22.842418           1.306578
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                       10.698335        111.920304

# %% [markdown]
# # 9.

# %%
df9_p2 = df_p2['neighbourhood'].value_counts()
df9_p2 = df9_p2.to_frame()
df9_p2 = df9_p2[df9_p2['neighbourhood']==1]
df9_p2
# Out:
#                 neighbourhood
# Woodrow                     1
# Richmondtown                1
# New Dorp                    1
# Fort Wadsworth              1
# Rossville                   1
# Willowbrook                 1

# %% [markdown]
# # 10.

# %%
df_p2[['room_type','calculated_host_listings_count']].groupby('room_type').sum()
# Out:
#                  calculated_host_listings_count
# room_type
# Entire home/apt                          271834
# Private room                              72062
# Shared room                                5409

# %% [markdown]
# # 11.

# %%
df11_p2 = df_p2[['neighbourhood','number_of_reviews']].groupby('neighbourhood').sum()
df11_p2
# Out:
#                  number_of_reviews
# neighbourhood
# Allerton                      1803
# Arden Heights                   31
# Arrochar                       307
# Arverne                       2253
# Astoria                      19310
# ...                            ...
# Windsor Terrace               4324
# Woodhaven                     2792
# Woodlawn                       484
# Woodrow                          0
# Woodside                      5035
#
# [221 rows x 1 columns]

# %%
df11_p2[df11_p2['number_of_reviews'] == df11_p2['number_of_reviews'].max()]
# Out:
#                     number_of_reviews
# neighbourhood
# Bedford-Stuyvesant             110352

# %%
df11_p2 = df_p2[['neighbourhood_group','number_of_reviews']].groupby('neighbourhood_group').sum()
df11_p2
# Out:
#                      number_of_reviews
# neighbourhood_group
# Bronx                            28371
# Brooklyn                        486574
# Manhattan                       454569
# Queens                          156950
# Staten Island                    11541

# %%
df11_p2[df11_p2['number_of_reviews']==df11_p2['number_of_reviews'].max()]
# Out:
#                      number_of_reviews
# neighbourhood_group
# Brooklyn                        486574

# %% [markdown]
# # 12.

# %%
df12_p2 = df_p2[['neighbourhood_group','minimum_nights']].sort_values(['minimum_nights'])[::-1]
df12_p2.drop_duplicates(subset=['neighbourhood_group']).head(3)
# Out:
#       neighbourhood_group  minimum_nights
# 5767            Manhattan            1250
# 26341            Brooklyn             999
# 7355               Queens             500

# %% [markdown]
# # 13.

# %%
df_p2['host_id'].value_counts().head(10)
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 12243051      96
# 16098958      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: host_id, dtype: int64

# %% [markdown]
# # 14.

# %%
df14_p2 = df_p2.drop_duplicates('host_id')
df14_p2['host_name'].value_counts().head(10)
# Out:
# Michael    335
# David      318
# Alex       226
# Daniel     208
# Sarah      199
# John       188
# Andrew     163
# Chris      162
# Maria      161
# Anna       156
# Name: host_name, dtype: int64

# %% [markdown]
# # 15.

# %%
df_p2[['host_id','number_of_reviews']].groupby('host_id').sum().sort_values('number_of_reviews')[::-1].head(10)
# Out:
#            number_of_reviews
# host_id
# 37312959                2273
# 344035                  2205
# 26432133                2017
# 35524316                1971
# 40176101                1818
# 4734398                 1798
# 16677326                1355
# 6885157                 1346
# 219517861               1281
# 23591164                1269

# %% [markdown]
# # 16.

# %%
df_p2[['host_name','price']].groupby('host_name').mean().sort_values('price')[::-1].head(10)
# Out:
#                        price
# host_name
# Olson            9999.000000
# Rum              8500.000000
# Jay And Liz      6000.000000
# Sarah-B          5000.000000
# Sarah-2          5000.000000
# Nony             4200.000000
# Kathrine         3501.666667
# Jelena           3400.000000
# Luxury Property  3000.000000
# Rogelio          2999.000000

# %% [markdown]
# # 17.

# %%
print(df_p2.dtypes)
df_p2['last_review'] = pd.to_datetime(df_p2['last_review'])
df_p2['Year'] = df_p2['last_review'].apply(lambda x : x.year)
df_p2['Month'] = df_p2['last_review'].apply(lambda x : x.month)
df_p2
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# ...

# %% [markdown]
# # 18.

# %%
df_p2['last_review'] = pd.to_datetime(df_p2['last_review'])
df_p2['Time of the week'] = df_p2['last_review'].dt.day_name()
df18_p2 = df_p2
df18_p2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # 19.

# %%
import seaborn as sns

sns.countplot(x=df_p2['room_type'])

# %% [markdown]
# # 20.

# %%
import matplotlib.pyplot as plt

df20_p2 = df_p2['neighbourhood'].value_counts().to_frame().head(5)
df20_p2
plt.figure(figsize=(12,8))
plt.pie(data=df20_p2,x='neighbourhood',labels = df20_p2.index,textprops = dict(color ="white"),autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # 21.

# %%
import seaborn as sns

fig=plt.figure(figsize=(12,8))
sns.boxplot(x='neighbourhood_group' , y='number_of_reviews' , data=df_p2)

# %% [markdown]
# # 22.

# %%
df_corr = df_p2.corr()
df_corr
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.588290 -0.003125   0.090908
# host_id                         0.588290  1.000000  0.020224   0.127055
# latitude                       -0.003125  0.020224  1.000000   0.084788
# longitude                       0.090908  0.127055  0.084788   1.000000
# price                           0.010619  0.015309  0.033939  -0.150019
# minimum_nights                 -0.013224 -0.017364  0.024869  -0.062747
# number_of_reviews              -0.319760 -0.140106 -0.015389   0.059094
# reviews_per_month               0.291828  0.296417 -0.010142   0.145948
# calculated_host_listings_count  0.133272  0.154950  0.019517  -0.114713
# availability_365                0.085468  0.203492 -0.010983   0.082731
# Year                            0.407407  0.265958 -0.020564   0.101660
# Month                          -0.051368 -0.030284 -0.002245   0.000772
#
# ...

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.heatmap(df_corr, cmap = 'coolwarm')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='number_of_reviews', y='reviews_per_month' , data=df_p2)

# %% [markdown]
# # 23.

# %%
df23_p2 = df18_p2[df18_p2['Year'] == 2018][['Month','last_review']]
df23_p2
# Out:
#        Month last_review
# 0       10.0  2018-10-19
# 4       11.0  2018-11-19
# 14      10.0  2018-10-31
# 42       9.0  2018-09-30
# 61      11.0  2018-11-03
# ...      ...         ...
# 39979   12.0  2018-12-30
# 39980   12.0  2018-12-31
# 39982   12.0  2018-12-30
# 40138   12.0  2018-12-31
# 40153   12.0  2018-12-31
#
# [6050 rows x 2 columns]

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.countplot(x=df23_p2['Month'])

# %% [markdown]
# # 24.

# %%
df24_p2 = df18_p2['Time of the week'].value_counts()
plt.figure(figsize=(12,8))
plt.pie(x= df24_p2.values, labels= df24_p2.index, autopct= '%1.2f%%', data= df24_p2,textprops = dict(color ="white"))
# Out:
# ([<matplotlib.patches.Wedge at 0x7f940b3bec10>,
# ...
#  [Text(0.7982215259125183, 0.7568635250624057, 'Sunday'),
#   Text(-0.5535147249472275, 0.9505900532125272, 'Monday'),
#   Text(-1.0998488046878594, 0.018237511526711693, 'Saturday'),
#   Text(-0.755926969041094, -0.7991085142058901, 'Tuesday'),
#   Text(-0.013567252140063974, -1.0999163284856572, 'Friday'),
#   Text(0.6854908635257219, -0.860291971381089, 'Wednesday'),
#   Text(1.054868510792704, -0.3118532105622501, 'Thursday')],
#  [Text(0.4353935595886463, 0.41283465003403946, '24.15%'),
#   Text(-0.30191712269848775, 0.5185036653886511, '18.48%'),
#   Text(-0.5999175298297414, 0.00994773356002456, '14.21%'),
#   Text(-0.4123238012951421, -0.4358773713850309, '12.20%'),
#   Text(-0.007400319349125804, -0.5999543609921766, '11.52%'),
#   Text(0.37390410737766644, -0.46925016620786664, '10.28%'),
#   Text(0.5753828240687475, -0.17010175121577278, '9.15%')])

# %% [markdown]
# # 25.

# %%
df25_p2 = df18_p2[df18_p2['Year']==2019].groupby('Month').mean()
display(df25_p2)
sns.lineplot(data=df25_p2,x=df25_p2.index,y='price')
# Out:
#                  id       host_id   latitude  longitude       price  \
# Month
# 1.0    1.916340e+07  5.666298e+07  40.727933 -73.952670  140.556250
# 2.0    2.113911e+07  7.422786e+07  40.725412 -73.951761  145.612766
# 3.0    2.047457e+07  6.920530e+07  40.727542 -73.952368  136.243902
# 4.0    1.960879e+07  6.397537e+07  40.728177 -73.952468  143.211538
# 5.0    1.982808e+07  6.846423e+07  40.728663 -73.951135  139.526373
# 6.0    2.043008e+07  8.100726e+07  40.727724 -73.947732  141.613443
# 7.0    2.284455e+07  9.316197e+07  40.723930 -73.942138  144.487831
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# Month
# 1.0          7.617361          14.409722           0.550118
# 2.0          9.387234          15.351064           0.658766
# 3.0         10.297561          13.789024           0.654805
# 4.0          7.781593          17.052198           0.751731
# 5.0          7.459021          23.393562           1.052413
# ...

# %% [markdown]
# # 26.

# %%
import datetime;
ts = datetime.datetime.now()

df18_p2['diff days'] = df18_p2['last_review'].apply(lambda x: (ts-x).days)
df18_p2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# # 27.

# %%
df27_p2 = df18_p2.groupby('neighbourhood_group')[['diff days']].sum()
df27_p2
# Out:
#                       diff days
# neighbourhood_group
# Bronx                  489199.0
# Brooklyn             11714715.0
# Manhattan            12189602.0
# Queens                2784965.0
# Staten Island          164094.0

# %%
plt.figure(figsize=(12,8))
plt.pie(x= df27_p2.values.flatten(), labels= df27_p2.index, autopct= '%1.2f%%', data= df27_p2,textprops = dict(color ="white"))
# Out:
# ([<matplotlib.patches.Wedge at 0x7f940a114a50>,
# ...
#  [Text(1.0982628375639396, 0.06179595153408908, 'Bronx'),
#   Text(0.12336855301516977, 1.093060016708572, 'Brooklyn'),
#   Text(-0.5345324333463317, -0.9613922600587388, 'Manhattan'),
#   Text(1.030377647538655, -0.38512582807792517, 'Queens'),
#   Text(1.099804499524066, -0.02073795618230053, 'Staten Island')],
#  [Text(0.599052456853058, 0.03370688265495768, '1.79%'),
#   Text(0.06729193800827442, 0.5962145545683118, '42.84%'),
#   Text(-0.2915631454616355, -0.5243957782138574, '44.58%'),
#   Text(0.5620241713847208, -0.21006863349705007, '10.19%'),
#   Text(0.5998933633767631, -0.011311612463073014, '0.60%')])

# %% [markdown]
# # 28.

# %%
df28_p2 = df18_p2.groupby('neighbourhood').mean().sort_values('diff days')[::-1][['diff days']].dropna().head(10)
df28_p2
# Out:
#                        diff days
# neighbourhood
# Co-op City           1203.000000
# Sea Gate             1032.000000
# Battery Park City    1019.888889
# Marble Hill           989.200000
# Mount Eden            947.400000
# Morningside Heights   883.793651
# Civic Center          852.333333
# Kensington            829.028571
# Roosevelt Island      828.303030
# Upper West Side       825.628880

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df28_p2,x=df28_p2.index,y='diff days')

# %% [markdown]
# # 29.

# %%
df29_p2 = df18_p2.groupby('neighbourhood').mean().sort_values('diff days')[['diff days']].dropna().head(10)
df29_p2
# Out:
#                     diff days
# neighbourhood
# Huguenot           428.333333
# Eltingville        432.000000
# Rossville          434.000000
# Castleton Corners  435.000000
# Mill Basin         435.000000
# Neponsit           437.666667
# Tottenville        438.800000
# New Brighton       439.200000
# Belle Harbor       440.400000
# Rosebank           441.285714

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df29_p2,x=df29_p2.index,y='diff days')

# %% [markdown]
# # 30.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x= df18_p2['diff days'], y= df18_p2['minimum_nights'])
