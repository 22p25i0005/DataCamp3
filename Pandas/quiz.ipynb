# %% [markdown]
# # 1.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 2.

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 584          585         0       3
# 673          674         1       2
# 255          256         1       3
# 635          636         1       2
# 744          745         1       3
# 867          868         0       1
# 218          219         1       1
# 346          347         1       2
# 77            78         0       3
# 343          344         0       2
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 584                         Paulner, Mr. Uscher    male   NaN      0      0
# 673                       Wilhelms, Mr. Charles    male  31.0      0      0
# 255     Touma, Mrs. Darwis (Hanne Youssef Razi)  female  29.0      0      2
# 635                           Davis, Miss. Mary  female  28.0      0      0
# 744                          Stranden, Mr. Juho    male  31.0      0      0
# 867        Roebling, Mr. Washington Augustus II    male  31.0      0      0
# ...

# %% [markdown]
# # 3.

# %%
df3 = df.dropna()

# %%
df3['Embarked'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 4.

# %%
mean = df['Age'].mean()
print(mean)
df4 = df.fillna(mean)
df4
# Out:
# 29.69911764705882
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# # 5.

# %%
df5 = df.fillna(0)
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 6.

# %%
df6 = df['Age'].dropna()
print(df6.isnull().sum())
df6
# Out:
# 0
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %% [markdown]
# # 7.

# %%
count = df['Sex'].value_counts()
print(count)
print('ผู้หญิงต่อผู้ชาย ',314/577)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# ผู้หญิงต่อผู้ชาย  0.5441941074523396

# %% [markdown]
# # 8.

# %%
df8 = df[df['Survived']==1]
print(df8.shape)
df8 = df8[['Sex','Survived']]
df8.groupby('Sex').describe()
print('ผู้หญิงรอดชีวิต ',233)
print('ผู้ชายรอดชีวิต ',109)
# Out:
# (342, 12)
# ผู้หญิงรอดชีวิต  233
# ผู้ชายรอดชีวิต  109

# %% [markdown]
# # 9.

# %%
df9 = df[df['Survived']==1]
df9 = df9[['Sex','Survived']]
df9.groupby('Sex').describe()
print('ผู้หญิงรอดชีวิต {}%'.format((233/314)*100))
print('ผู้ชายรอดชีวิต {}%'.format((109/577)*100))
# Out:
# ผู้หญิงรอดชีวิต 74.20382165605095%
# ผู้ชายรอดชีวิต 18.890814558058924%

# %% [markdown]
# # 10.

# %%
df.loc[df['Sex'] == 'male', 'Sex'] = 1
df.loc[df['Sex'] == 'female', 'Sex'] = 0
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0      1
# 2                               Heikkinen, Miss. Laina   0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0      1
# 4                             Allen, Mr. William Henry   1  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %% [markdown]
# # 11.

# %%
df11 = df[df['Age'].notnull()]
df11.sort_values('Age')[::-1]
# Out:
#      PassengerId  Survived  Pclass                                  Name Sex  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson   1
# 851          852         0       3                   Svensson, Mr. Johan   1
# 96            97         0       1             Goldschmidt, Mr. George B   1
# 493          494         0       1               Artagaveytia, Mr. Ramon   1
# 116          117         0       3                  Connors, Mr. Patrick   1
# ..           ...       ...     ...                                   ...  ..
# 78            79         1       2         Caldwell, Master. Alden Gates   1
# 469          470         1       3         Baclini, Miss. Helene Barbara   0
# 644          645         1       3                Baclini, Miss. Eugenie   0
# 755          756         1       2             Hamalainen, Master. Viljo   1
# 803          804         1       3       Thomas, Master. Assad Alexander   1
#
# ...

# %%
print('Barkworth, Mr. Algernon Henry Wilson อายุ 80 ลงท่า Southampton')
# Out:
# Barkworth, Mr. Algernon Henry Wilson อายุ 80 ลงท่า Southampton

# %% [markdown]
# # 12.

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
print('Thomas, Master. Assad Alexander อายุ 0.42 ลงท่า Cherbourg')
# Out:
# Thomas, Master. Assad Alexander อายุ 0.42 ลงท่า Cherbourg

# %% [markdown]
# # 13.

# %%
df.sort_values('Fare')[::-1]
# Out:
#      PassengerId  Survived  Pclass                                Name Sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez   1
# 258          259         1       1                    Ward, Miss. Anna   0
# 737          738         1       1              Lesurer, Mr. Gustave J   1
# 341          342         1       1      Fortune, Miss. Alice Elizabeth   0
# 438          439         0       1                   Fortune, Mr. Mark   1
# ..           ...       ...     ...                                 ...  ..
# 277          278         0       2         Parkes, Mr. Francis "Frank"   1
# 633          634         0       1       Parr, Mr. William Henry Marsh   1
# 302          303         0       3     Johnson, Mr. William Cahoone Jr   1
# 597          598         0       3                 Johnson, Mr. Alfred   1
# 271          272         1       3        Tornquist, Mr. William Henry   1
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
print('Cardeza, Mr. Thomas Drake Martinez อายุ 36 รอดชีวิต')
# Out:
# Cardeza, Mr. Thomas Drake Martinez อายุ 36 รอดชีวิต

# %% [markdown]
# # 14.

# %%
df.sort_values('Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name Sex  \
# 271          272         1       3        Tornquist, Mr. William Henry   1
# 597          598         0       3                 Johnson, Mr. Alfred   1
# 302          303         0       3     Johnson, Mr. William Cahoone Jr   1
# 633          634         0       1       Parr, Mr. William Henry Marsh   1
# 277          278         0       2         Parkes, Mr. Francis "Frank"   1
# ..           ...       ...     ...                                 ...  ..
# 438          439         0       1                   Fortune, Mr. Mark   1
# 341          342         1       1      Fortune, Miss. Alice Elizabeth   0
# 737          738         1       1              Lesurer, Mr. Gustave J   1
# 258          259         1       1                    Ward, Miss. Anna   0
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez   1
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
print('Tornquist, Mr. William Henry	อายุ 25 รอดชีวิต')
# Out:
# Tornquist, Mr. William Henry	อายุ 25 รอดชีวิต

# %% [markdown]
# # 15.

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# # 16.

# %%
df16 = df.groupby(['Pclass']).describe()
df16
print('ค่าเฉลี่ยราคาตั๋ว ชั้น 1: {} , ค่าเฉลี่ยราคาตั๋ว ชั้น 2: {} , ค่าเฉลี่ยราคาตั๋ว ชั้น 3: {} '.format(84.154687,20.662183,13.675550))
# dftest = df[df['Pclass']==1]['Fare'].mean()
# dftest
# Out:
# ค่าเฉลี่ยราคาตั๋ว ชั้น 1: 84.154687 , ค่าเฉลี่ยราคาตั๋ว ชั้น 2: 20.662183 , ค่าเฉลี่ยราคาตั๋ว ชั้น 3: 13.67555

# %% [markdown]
# # 17.

# %%
df[(df['Age']>50) & (df['Survived']==1)].shape
# Out:
# (22, 12)

# %%
print('22 คน')
# Out:
# 22 คน

# %% [markdown]
# # 18.

# %%
df.groupby(['Pclass']).describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std   min     25%    50%    75%    max
# Pclass
# 1            216.0  461.597222  246.737616   2.0  270.75  472.0  670.5  890.0
# 2            184.0  445.956522  250.852161  10.0  234.50  435.5  668.0  887.0
# 3            491.0  439.154786  264.441453   1.0  200.00  432.0  666.5  891.0
#
#        Survived            ... Parch        Fare                             \
#           count      mean  ...   75%  max  count       mean        std  min
# Pclass                     ...
# 1         216.0  0.629630  ...   0.0  4.0  216.0  84.154687  78.380373  0.0
# 2         184.0  0.472826  ...   1.0  3.0  184.0  20.662183  13.417399  0.0
# 3         491.0  0.242363  ...   0.0  6.0  491.0  13.675550  11.778142  0.0
#
#
#              25%      50%   75%       max
# Pclass
# 1       30.92395  60.2875  93.5  512.3292
# 2       13.00000  14.2500  26.0   73.5000
# ...

# %% [markdown]
# # 19.

# %%
print('ค่าตั๋วแพงสุด ชั้นที่ 1: {} , ชั้นที่ 2: {} , ชั้นที่ 3: {}'.format(512.3292,73.5000,69.5500))
# Out:
# ค่าตั๋วแพงสุด ชั้นที่ 1: 512.3292 , ชั้นที่ 2: 73.5 , ชั้นที่ 3: 69.55

# %% [markdown]
# # 20.

# %%
df20_1 = df[df['Age']<10]
print(df20_1.shape)
df20_1 = df20_1[df20_1['Survived']==1]
(df20_1['Survived'].value_counts()/62)*100
# Out:
# (62, 12)
# 1    61.290323
# Name: Survived, dtype: float64

# %%
df20_2 = df[(df['Age']>10) & (df['Age']<20)]
print(df20_2.shape)
df20_2 = df20_2[df20_2['Survived']==1]
(df20_2['Survived'].value_counts()/100)*100
# Out:
# (100, 12)
# 1    41.0
# Name: Survived, dtype: float64

# %%
df20_3 = df[(df['Age']>20) & (df['Age']<30)]
print(df20_3.shape)
df20_3 = df20_3[df20_3['Survived']==1]
(df20_3['Survived'].value_counts()/205)*100
# Out:
# (205, 12)
# 1    36.097561
# Name: Survived, dtype: float64

# %%
df20_4 = df[(df['Age']>30) & (df['Age']<40)]
print(df20_4.shape)
df20_4 = df20_4[df20_4['Survived']==1]
(df20_4['Survived'].value_counts()/142)*100
# Out:
# (142, 12)
# 1    44.366197
# Name: Survived, dtype: float64

# %%
df20_5 = df[(df['Age']>40) & (df['Age']<50)]
print(df20_5.shape)
df20_5 = df20_5[df20_5['Survived']==1]
(df20_5['Survived'].value_counts()/76)*100
# Out:
# (76, 12)
# 1    36.842105
# Name: Survived, dtype: float64

# %%
df20_6 = df[(df['Age']>50) & (df['Age']<60)]
print(df20_6.shape)
df20_6 = df20_6[df20_6['Survived']==1]
(df20_6['Survived'].value_counts()/38)*100
# Out:
# (38, 12)
# 1    39.473684
# Name: Survived, dtype: float64

# %%
df20_7 = df[(df['Age']>60) & (df['Age']<70)]
print(df20_7.shape)
df20_7 = df20_7[df20_7['Survived']==1]
(df20_7['Survived'].value_counts()/15)*100
# Out:
# (15, 12)
# 1    26.666667
# Name: Survived, dtype: float64

# %%
df20_8 = df[(df['Age']>70) & (df['Age']<80)]
print(df20_8.shape)
df20_8 = df20_8[df20_8['Survived']==1]
display(df20_8)
(df20_8['Survived'].value_counts()/4)*100
print(0)
# Out:
# (4, 12)
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
# 0

# %%
print('อายุ 0-10: {}\nอายุ 10-20: {}\nอายุ 20-30: {}\nอายุ 30-40: {}\nอายุ 40-50: {}\nอายุ 50-60: {}\nอายุ 60-70: {}\nอายุ 70-80: {}'.format(61.290323,41.0,36.097561,44.366197,36.842105,39.473684,26.666667,0))
# Out:
# อายุ 0-10: 61.290323
# อายุ 10-20: 41.0
# อายุ 20-30: 36.097561
# อายุ 30-40: 44.366197
# อายุ 40-50: 36.842105
# อายุ 50-60: 39.473684
# อายุ 60-70: 26.666667
# อายุ 70-80: 0

# %% [markdown]
# # 21.

# %%
df.sort_values('Fare')[::-1]
# Out:
#      PassengerId  Survived  Pclass                                Name Sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez   1
# 258          259         1       1                    Ward, Miss. Anna   0
# 737          738         1       1              Lesurer, Mr. Gustave J   1
# 341          342         1       1      Fortune, Miss. Alice Elizabeth   0
# 438          439         0       1                   Fortune, Mr. Mark   1
# ..           ...       ...     ...                                 ...  ..
# 277          278         0       2         Parkes, Mr. Francis "Frank"   1
# 633          634         0       1       Parr, Mr. William Henry Marsh   1
# 302          303         0       3     Johnson, Mr. William Cahoone Jr   1
# 597          598         0       3                 Johnson, Mr. Alfred   1
# 271          272         1       3        Tornquist, Mr. William Henry   1
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values('Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name Sex  \
# 271          272         1       3        Tornquist, Mr. William Henry   1
# 597          598         0       3                 Johnson, Mr. Alfred   1
# 302          303         0       3     Johnson, Mr. William Cahoone Jr   1
# 633          634         0       1       Parr, Mr. William Henry Marsh   1
# 277          278         0       2         Parkes, Mr. Francis "Frank"   1
# ..           ...       ...     ...                                 ...  ..
# 438          439         0       1                   Fortune, Mr. Mark   1
# 341          342         1       1      Fortune, Miss. Alice Elizabeth   0
# 737          738         1       1              Lesurer, Mr. Gustave J   1
# 258          259         1       1                    Ward, Miss. Anna   0
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez   1
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# # 22.

# %%
new = df['Name'].apply(lambda x : x.split(',')[0])
new[new.duplicated()].value_counts()
# Out:
# Andersson        8
# Sage             6
# Panula           5
# Skoog            5
# Carter           5
#                 ..
# Chambers         1
# Beane            1
# Daly             1
# Nicola-Yarred    1
# Mellinger        1
# Name: Name, Length: 133, dtype: int64

# %% [markdown]
# # 23.

# %%
new = df['Name'].apply(lambda x : x.split(',')[0])
new.unique().shape

print('นามสกุลไม่ซ้ำ 667')
# Out:
# นามสกุลไม่ซ้ำ 667
